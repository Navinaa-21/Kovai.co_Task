# %% [markdown]
# <a href="https://colab.research.google.com/github/Navinaa-21/Kovai.co_Task/blob/main/Forcast_of_ACT_Public_Transport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

df = pd.read_csv('/content/Daily_Public_Transport_Passenger_Journeys_by_Service_Type_20250526.csv')

df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

forecast_columns = ['Local Route', 'Light Rail', 'Peak Service', 'Rapid Route', 'School', 'Other']

for column in forecast_columns:
    print(f"\n--- Forecasting: {column} ---\n")

    data = df[['Date', column]].rename(columns={'Date': 'ds', column: 'y'})


    data = data.dropna()
    data['y'] = pd.to_numeric(data['y'], errors='coerce')
    data = data.dropna()


    model = Prophet()
    model.fit(data)

    future = model.make_future_dataframe(periods=7)


    forecast = model.predict(future)

    fig = model.plot(forecast)
    plt.title(f"{column} - Forecast for Next 7 Days")
    plt.xlabel("Date")
    plt.ylabel(column)
    plt.grid(True)
    plt.show()


    forecast_result = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)
    print(forecast_result)


    forecast_result.to_csv(f"{column.replace(' ', '_')}_forecast.csv", index=False)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj_0evy6c/npt9_o3m.json
# --- Forecasting: Local Route ---
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj_0evy6c/gwpep1p9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53776', 'data', 'file=/tmp/tmpj_0evy6c/npt9_o3m.json', 'init=/tmp/tmpj_0evy6c/gwpep1p9.json', 'output', 'file=/tmp/tmpj_0evy6c/prophet_model28mu6g4g/prophet_model-20250526062547.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:25:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:25:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj_0evy6c/h5xkkaa4.json
#              ds          yhat   yhat_lower    yhat_upper
# 1918 2024-09-30  10495.099677  6690.777268  14564.348856
# 1919 2024-10-01  12290.212671  8375.315484  16635.109080
# 1920 2024-10-02  12454.564899  8156.248182  16366.239226
# 1921 2024-10-03  12304.106031  8181.179383  16130.469622
# 1922 2024-10-04  11774.630519  7834.370081  15911.657325
# 1923 2024-10-05   2626.683795 -1218.719581   6579.598378
# 1924 2024-10-06   1701.722160 -2257.088022   5798.941494
#
# --- Forecasting: Light Rail ---
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj_0evy6c/5j3wo024.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48454', 'data', 'file=/tmp/tmpj_0evy6c/h5xkkaa4.json', 'init=/tmp/tmpj_0evy6c/5j3wo024.json', 'output', 'file=/tmp/tmpj_0evy6c/prophet_modelkcqm1hik/prophet_model-20250526062548.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:25:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:25:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj_0evy6c/d30vqqaw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj_0evy6c/ir3u8i22.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62093', 'data', 'file=/tmp/tmpj_0evy6c/d30vqqaw.json', 'init=/tmp/tmpj_0evy6c/ir3u8i22.json', 'output', 'file=/tmp/tmpj_0evy6c/prophet_model01ek46bu/prophet_model-20250526062550.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:25:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#              ds         yhat   yhat_lower    yhat_upper
# 1918 2024-09-30  7583.443077  5299.828748   9778.103618
# 1919 2024-10-01  8637.506094  6136.500539  11117.546619
# 1920 2024-10-02  8680.287395  6395.584227  10999.065087
# 1921 2024-10-03  8599.768342  6275.181788  10972.784312
# 1922 2024-10-04  8629.938528  6251.399679  10944.646373
# 1923 2024-10-05  5166.143206  2748.916060   7668.883033
# 1924 2024-10-06  3808.671451  1380.892446   5983.156724
#
# --- Forecasting: Peak Service ---
# 06:25:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj_0evy6c/ch1j_tpj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj_0evy6c/5koyrz0u.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85197', 'data', 'file=/tmp/tmpj_0evy6c/ch1j_tpj.json', 'init=/tmp/tmpj_0evy6c/5koyrz0u.json', 'output', 'file=/tmp/tmpj_0evy6c/prophet_model1_wi81nb/prophet_model-20250526062551.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:25:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#              ds        yhat  yhat_lower  yhat_upper
# 1918 2024-09-30  223.811426  126.239554  321.113772
# 1919 2024-10-01  269.251305  165.849431  371.209652
# 1920 2024-10-02  269.020228  172.431199  361.909289
# 1921 2024-10-03  242.469110  145.775057  352.248687
# 1922 2024-10-04  190.810618   99.138097  295.163962
# 1923 2024-10-05  -11.079756 -109.396987   93.081963
# 1924 2024-10-06   -9.691342 -108.534733   97.832566
#
# --- Forecasting: Rapid Route ---
# 06:25:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj_0evy6c/_bzwori4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj_0evy6c/m6xev645.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53246', 'data', 'file=/tmp/tmpj_0evy6c/_bzwori4.json', 'init=/tmp/tmpj_0evy6c/m6xev645.json', 'output', 'file=/tmp/tmpj_0evy6c/prophet_model0xgbegae/prophet_model-20250526062552.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:25:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#              ds          yhat    yhat_lower    yhat_upper
# 1918 2024-09-30  13451.439464   8424.898260  18379.325711
# 1919 2024-10-01  15558.779105  11338.290822  20276.615932
# 1920 2024-10-02  15645.997454  10984.000279  20143.253385
# 1921 2024-10-03  15456.805596  10522.204777  19956.135456
# 1922 2024-10-04  14750.267918  10045.355431  19442.770600
# 1923 2024-10-05   6564.267773   1911.807179  11186.571020
# 1924 2024-10-06   5115.324841    542.370530  10099.630786
#
# --- Forecasting: School ---
# 06:25:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj_0evy6c/rf1g981h.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpj_0evy6c/rynrrv_s.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.11/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65020', 'data', 'file=/tmp/tmpj_0evy6c/rf1g981h.json', 'init=/tmp/tmpj_0evy6c/rynrrv_s.json', 'output', 'file=/tmp/tmpj_0evy6c/prophet_modelu8h5ogl8/prophet_model-20250526062553.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 06:25:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
#              ds         yhat   yhat_lower   yhat_upper
# 1918 2024-09-30  1424.605397  -516.471945  3258.620790
# 1919 2024-10-01  1848.711346  -174.729871  3849.304243
# 1920 2024-10-02  1909.190565   -90.495806  3906.456072
# 1921 2024-10-03  1811.524961  -239.875254  3712.892761
# 1922 2024-10-04  1629.324184  -368.607213  3590.668641
# 1923 2024-10-05 -1410.416213 -3123.704385   701.600343
# 1924 2024-10-06 -1301.995643 -3223.187060   516.029241
#
# --- Forecasting: Other ---
# 06:25:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#              ds       yhat  yhat_lower  yhat_upper
# 1898 2024-09-24  60.166546   18.985300  101.409880
# 1899 2024-09-25  63.617577   21.393005  104.210308
# 1900 2024-09-26  65.478876   24.538977  105.452386
# 1901 2024-09-27  61.706515   21.815632  100.224266
# 1902 2024-09-28  25.599784  -13.620333   65.558630
# 1903 2024-09-29  24.646047  -15.440244   66.891035
# 1904 2024-09-30  51.555730   12.316920   91.010446
